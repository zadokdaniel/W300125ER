# %% [markdown]
# # Exercise - Error Handling (10 min)
#
# ---

# %% [markdown]
# ## 1. Fix the Broken Code
# This code has **3 different errors** that happen one after another.
# Wrap it in `try/except` blocks to catch each one **specifically** (not a bare `except`).
# Print a helpful message for each.
#
# ```
# Hint: NameError, TypeError, ZeroDivisionError
# ```

# %%
# This code will crash - wrap it to handle all 3 errors

print(x)
result = "10" + 5
answer = 100 / 0

# %% [markdown]
# ## 2. Safe Division
# Write a function-like block (no need for `def`, just code) that:
# - Takes two numbers from the user with `input()`
# - Converts them to `int()`
# - Divides the first by the second
# - Handle `ValueError` (user typed letters instead of numbers)
# - Handle `ZeroDivisionError` (user typed 0 as the second number)
# - Use `finally` to print `"Calculation attempt finished."`

# %%
# Your code here

# %% [markdown]
# ## 3. Raise It Yourself
# Ask the user for their age with `input()`.
# - Convert to `int()`
# - If the age is **negative**, `raise ValueError("Age cannot be negative")`
# - If the age is **greater than 120**, `raise ValueError("Age is not realistic")`
# - Wrap the whole thing in `try/except` to catch both the `ValueError` you raised **and** a possible `ValueError` from `int()` conversion (e.g. user types "abc")

# %%
# Your code here

# %% [markdown]
# ## 4. What Gets Printed?
# **Without running the code** - write in a comment what each block prints, then run to check yourself.

# %%
# Block A - what gets printed?
# Your answer: 

try:
    print("one")
    x = 1 / 0
    print("two")
except ZeroDivisionError:
    print("three")
finally:
    print("four")

# %%
# Block B - what gets printed?
# Your answer: 

try:
    print("one")
    print("two")
except ZeroDivisionError:
    print("three")
finally:
    print("four")

# %%
# Block C - what gets printed?
# Your answer: 

try:
    print("one")
    x = int("hello")
except ZeroDivisionError:
    print("two")
except ValueError:
    print("three")
except:
    print("four")
finally:
    print("five")

# %% [markdown]
# ## 5. Bonus - Access by Key
# Given this dictionary:
# ```python
# user = {"name": "Alice", "age": 25}
# ```
# Ask the user to type a key name with `input()`.
# - Try to print the value using `user[key]`
# - Handle `KeyError` and print which key was not found (use `as err`)

# %%
user = {"name": "Alice", "age": 25}

# Your code here
