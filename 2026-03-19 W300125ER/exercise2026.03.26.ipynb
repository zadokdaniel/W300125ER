# %% [markdown]
# # Exercise - Loops, Range & Iteration (26.03.2026)
# **Time: 30 minutes**
#
# ---

# %% [markdown]
# ## Exercise 1 - Range Basics
# Using `range()` and a `for` loop:
# 1. Print all numbers from 1 to 20 (inclusive)
# 2. Print all **even** numbers from 2 to 30 (inclusive)
# 3. Print numbers from 50 down to 0, counting backwards by 5 (50, 45, 40, ...)

# %%
# Your code here

# %% [markdown]
# ## Exercise 2 - While Loop: Guessing Game
# Create a simple number guessing game:
# - The secret number is `7`
# - Ask the user to guess a number using `input()`
# - While the guess is wrong, print `"Wrong! Try again"` and ask again
# - Use `while...else` - in the `else` block print `"Correct! You guessed it!"`
#
# *Hint: remember to convert `input()` to `int()`*

# %%
# Your code here

# %% [markdown]
# ## Exercise 3 - Iterating Over a Dictionary
# Given this dictionary:
# ```python
# student_grades = {"Alice": 92, "Bob": 85, "Charlie": 78, "Diana": 95, "Eve": 88}
# ```
# Using `for` loops:
# 1. Print only the student **names** (keys)
# 2. Print only the **grades** (values)
# 3. Using `.items()` and tuple unpacking, print: `"Alice got 92"` for each student
# 4. Using `enumerate()` with `start=1`, print: `"1. Alice - 92"` for each student

# %%
student_grades = {"Alice": 92, "Bob": 85, "Charlie": 78, "Diana": 95, "Eve": 88}

# 1. Print names


# 2. Print grades


# 3. Print "Name got Grade" using .items()


# 4. Print numbered list using enumerate()

# %% [markdown]
# ## Exercise 4 - For...Else: Find the Element
# Given this list:
# ```python
# numbers = [10, 23, 45, 67, 89, 12, 34]
# ```
# Write a `for` loop that searches for a number greater than 100.
# - If found, print `"Found: <number>"` and `break`
# - Use `for...else` - in the `else` block print `"No number greater than 100 was found"`
#
# Then test it again by adding `150` to the list and running again.

# %%
numbers = [10, 23, 45, 67, 89, 12, 34]

# Your code here

# %% [markdown]
# ## Exercise 5 - Iterating Different Data Types
# Given:
# ```python
# my_list = ["Python", "JavaScript", "TypeScript", "Java", "C#"]
# my_tuple = (100, 200, 300, 400, 500)
# my_string = "Hello"
# ```
# 1. Loop over `my_list` and print each language in UPPERCASE (use `.upper()`)
# 2. Loop over `my_tuple` and print each value divided by 10
# 3. Loop over `my_string` and print each character with its index using `enumerate()`
#    Expected output: `"0 -> H"`, `"1 -> e"`, etc.

# %%
my_list = ["Python", "JavaScript", "TypeScript", "Java", "C#"]
my_tuple = (100, 200, 300, 400, 500)
my_string = "Hello"

# 1. Uppercase languages


# 2. Divide tuple values


# 3. Enumerate string characters

# %% [markdown]
# ## Exercise 6 - While + Slicing Combo
# Given this list:
# ```python
# data = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
# ```
# 1. Use **slicing** to get only the last 5 elements into a new variable `last_five`
# 2. Use a **while loop** to pop (remove) elements from `last_five` one by one from the end and print them, until the list is empty
# 3. When the loop ends, use `while...else` to print `"List is now empty!"`
#
# *Hint: check `len()` in the while condition, use `.pop()` to remove the last element*

# %%
data = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

# Your code here

# %% [markdown]
# ## Bonus Exercise - Build a Shopping Receipt
# Given:
# ```python
# cart = {"Milk": 5.90, "Bread": 12.50, "Eggs": 11.90, "Cheese": 25.00, "Butter": 8.50}
# ```
# 1. Use a `for` loop with `.items()` and `enumerate(start=1)` to print a numbered receipt:
#    ```
#    1. Milk ......... 5.90
#    2. Bread ........ 12.50
#    ```
# 2. Use a separate loop (or use a variable during the loop) to calculate and print the **total** at the end
# 3. Use `for...else` to print `"--- Thank you for shopping! ---"` after the loop finishes
#
# *Hint: you can combine `enumerate()` with `.items()` like this: `for i, (name, price) in enumerate(cart.items(), start=1)`*

# %%
cart = {"Milk": 5.90, "Bread": 12.50, "Eggs": 11.90, "Cheese": 25.00, "Butter": 8.50}

# Your code here
