# %% [markdown]
# # https://chatgpt.com/share/69c17249-8408-8000-a051-0aa29084baf4
#
#
# ### Exercise 1 — User Input, Type Conversion, and Basic Logic
#
# **Goal:**
# Understand how Python handles input, type conversion, comparisons, and logical operations.
#
# **Task:**
# Create a program that asks the user to enter:
# - their name
# - their age
# - their height (in meters)
# - whether they are a student (type “yes” or “no”)
#
# **Steps:**
# 1. Convert the inputs into correct types:
#    - age → integer
#    - height → float
#    - student → boolean (based on comparison, not by wrapping with `bool()`)
#
# 2. Print a clear summary of the user:
#    - use formatted strings (f-strings)
#    - also use string concatenation at least once
#    - also use `print` with multiple arguments
#
# 3. Check and print:
#    - if age as integer equals age as float
#    - if they are the same object (identity)
#    - if the letter `"a"` exists in the name
#    - if the name is empty
#    - if the user is both adult (age ≥ 18) and a student
#    - if the user is minor OR not a student
#
# 4. Create a fallback name:
#    - if the name is empty → use `"Anonymous"`
#    - otherwise → use the real name
#
# 5. Inspect one variable using a built-in inspection tool and print the result
#
# **Focus on:**
# - type conversion
# - equality vs identity
# - logical operators (`and`, `or`, `not`)
# - short-circuit behavior
# - string formatting

# %%
name = input("what is your name?")
age = int(input("what is your age?"))
height = float(input("what is your height in meters"))
student_status = input("are you a student? (yes/no)")

if student_status == "yes" or student_status == "no":
    if student_status == "yes":
        is_student = True
    elif student_status == "no": 
        is_student = False 
        
    print("your", "name", "is", name)
    print("you are " f"{age} years old")
    print("""and your height is {height} meters
student: {is_student}
""".format(height=height, is_student=is_student))
    
    
    
    
    
    ##### check and print age as integer and if they the same identity
    # print("\n" * 2, "-" * 10, "if age as integer equals age as float")
    # print(age == float(age))
    
    print(f"""
    
if age as integer equals age as float
{"-" * 10}""")
    
    age_as_float = float(age)
    print("equality check: ", age == age_as_float)
    print("identity check: ", age is age_as_float)
    
    
    
    print("\n"*2, "if the letter 'a' exist in the name" "\n", "-" * 10, "\n the letter 'a' exist in name: ", 'a' in name)
    

else: 
    print("you must provide a valid 'yes' or 'no' to student. run the program again.")
# Out:
# your name is daniel
# you are 32 years old
# and your height is 4.4 meters
# student: True
#
#
#
# if age as integer equals age as float
# ----------
# equality check:  True
# identity check:  False
#
#
#  if the letter 'a' exist in the name
#  ---------- the letter 'a' exist in name:  True
